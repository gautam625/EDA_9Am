# %% [markdown]
# # Feature Engineearing
# - so for we have perform feature analysis
#     - Data from qucik checks
#     - catogrical column analysis
#     - Bar chart, Pie chart
#     - Numerical column anylisis
#     - Histogram, Boxplot,Outliers
#     - Bi mlutiti varient analysis
#     - correlation etc
# - now we need to learn Feature Engineering
#     - we will create a new columns for batter ML models
#     - we will perform the Encoding which convert catogries to numeric data
#     - we will do the transformation
#     - we will perform scaling standarzation and Normalization
#     - we will performe the missing value analysis
#     - Simply **Feature Engineearing** means our data will be modified

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\gauta\OneDrive\Desktop\Data\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - Feature Analysis
# - Feature Engineearing
# - Feature Selection
# - Model Devlopment
# - Model Evaluation
# - Module Tuning
# - Model deployment

# %% [markdown]
# **Encoding**
# - Encoding means to convert catogrical data to numerical data
# - ML/DL or any models works based on maths
# - model can not understand english characters
# - So it is very important convert catogrical label to numerical value
# - For example Gender colum has two lables
#     - Male
#     - Femail
# - Then Femail represent as 0, Male represent as 1 based on alphabetical order

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %% [markdown]
# - Certified shud assign as 0
# - Denied as 1

# %%
# Mapping
d={'Certified':0,"Denied":1}
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d1={'Asia':0, 'Africa':1, 'North America':2, 'Europe':3, 'South America':4,'Oceania':5}
visa_df['continent'].map(d1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64

# %%
lab=visa_df['continent'].unique()

d={j:i for i,j in enumerate(lab)}
visa_df['continent']=visa_df['continent'].map(d)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# I need to replace ovove 3 line for all cat column 
# Except case_id

# %%
visa_df=pd.read_csv(r"C:\Users\gauta\OneDrive\Desktop\Data\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns

for i in range(1,len(cat)):
    lab=sorted(visa_df[cat[i]].unique())
    d={j:i for i,j in enumerate(lab)}
    visa_df[cat[i]]=visa_df[cat[i]].map(d)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **LableEnvoder**
# - LabelEncoder is a method will convert cat lables to numerical values
# - It is under package **sklearn**(Sick-learn)
#   - The class Name: preprocessing
#     - The Method name: LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# - Step-1 : Import Method
# - Step-2 : Save method
# - Step-3 : Apply fit transform
# - **fit transform**
#   - **fit**:means fit the logic
#     - inabove example fit means create mapper or dic
#   - **transform**: apply the logic and change the data
#     - Apply mapping on the data

# %%
# Read the data
visa_df=pd.read_csv(r"C:\Users\gauta\OneDrive\Desktop\Data\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns

# Imort mrthod
from sklearn.preprocessing import LabelEncoder

# Save method
le=LabelEncoder()

# Apply fit Transform
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\gauta\OneDrive\Desktop\Data\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in visa_df.columns[1:]:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **OneHotEncoder**
# - How many new lables are ther in a column
# - That may new column will be created extra
# - for example case status has two lables
#     - Certifide
#     - Denied
# - So It will creat two new extra columns
#     - case_status_Certified
#     - case_status_Denied
# - At a time one column value become 1 other column value because 0
# - This means a**one hot encoder**

# %%
# continent     C_A      C_Af      C_E
# Asia           1         0        0
# Africa         0         1        0
# EUrope         0         0        1

# %% [markdown]
# # pd.ger_dummies

# %%
visa_df=pd.read_csv(r"C:\Users\gauta\OneDrive\Desktop\Data\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns

pd.get_dummies(visa_df['continent'])
# Out:
#        Africa   Asia  Europe  North America  Oceania  South America
# 0       False   True   False          False    False          False
# 1       False   True   False          False    False          False
# 2       False   True   False          False    False          False
# 3       False   True   False          False    False          False
# 4        True  False   False          False    False          False
# ...       ...    ...     ...            ...      ...            ...
# 25475   False   True   False          False    False          False
# 25476   False   True   False          False    False          False
# 25477   False   True   False          False    False          False
# 25478   False   True   False          False    False          False
# 25479   False   True   False          False    False          False
#
# [25480 rows x 6 columns]

# %%
pd.get_dummies(visa_df['case_status'],dtype=int)
# Out:
#        <class 'int'>_Certified  <class 'int'>_Denied
# 0                        False                  True
# 1                         True                 False
# 2                        False                  True
# 3                        False                  True
# 4                         True                 False
# ...                        ...                   ...
# 25475                     True                 False
# 25476                     True                 False
# 25477                     True                 False
# 25478                     True                 False
# 25479                     True                 False
#
# [25480 rows x 2 columns]
